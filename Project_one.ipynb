# %%
import pandas as pd
pew = pd.read_csv('pew.csv')
pew
# Out:
#                   RReliggon   <$10k   $10-20k  $20-30k  $30-40k   $40-50k  \
# 0                  Agnostic      27        34       60       81        76
# 1                   Atheist      12        27       37       52        35
# 2                  Buddhist      27        21       30       34        33
# 3                  Catholic     418       617      732      670       638
# 4         Dont know/refused      15        14       15       11        10
# 5         Evangelical Prot      575       869     1064      982       881
# 6                    Hindu        1         9        7        9        11
# 7  Historically Black Prot      228       244      236      238       197
# 8         Jehovahs Witness       20        27       24       24        21
# 9                   Jewish       19        19       25       25        30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
pew = pew.rename (columns={
    'RReliggon':'religion',
})
pew
# Out:
#                    religion   <$10k   $10-20k  $20-30k  $30-40k   $40-50k  \
# 0                  Agnostic      27        34       60       81        76
# 1                   Atheist      12        27       37       52        35
# 2                  Buddhist      27        21       30       34        33
# 3                  Catholic     418       617      732      670       638
# 4         Dont know/refused      15        14       15       11        10
# 5         Evangelical Prot      575       869     1064      982       881
# 6                    Hindu        1         9        7        9        11
# 7  Historically Black Prot      228       244      236      238       197
# 8         Jehovahs Witness       20        27       24       24        21
# 9                   Jewish       19        19       25       25        30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
pew.dtypes
# Out:
# religion    object
#  <$10k       int64
#  $10-20k     int64
# $20-30k      int64
# $30-40k      int64
#  $40-50k     int64
# $50-75k      int64
# dtype: object

# %%
pew
# Out:
#                    religion   <$10k   $10-20k  $20-30k  $30-40k   $40-50k  \
# 0                  Agnostic      27        34       60       81        76
# 1                   Atheist      12        27       37       52        35
# 2                  Buddhist      27        21       30       34        33
# 3                  Catholic     418       617      732      670       638
# 4         Dont know/refused      15        14       15       11        10
# 5         Evangelical Prot      575       869     1064      982       881
# 6                    Hindu        1         9        7        9        11
# 7  Historically Black Prot      228       244      236      238       197
# 8         Jehovahs Witness       20        27       24       24        21
# 9                   Jewish       19        19       25       25        30
#
#    $50-75k
# 0      137
# 1       70
# 2       58
# 3     1116
# 4       35
# 5     1486
# 6       34
# 7      223
# 8       30
# 9       95

# %%
pew.shape
# Out:
# (10, 7)

# %%
pew.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
pew.index.name = 'religion_id'

# %%
pew
# Out:
#                              religion   <$10k   $10-20k  $20-30k  $30-40k  \
# religion_id
# 0                            Agnostic      27        34       60       81
# 1                             Atheist      12        27       37       52
# 2                            Buddhist      27        21       30       34
# 3                            Catholic     418       617      732      670
# 4                   Dont know/refused      15        14       15       11
# 5                   Evangelical Prot      575       869     1064      982
# 6                              Hindu        1         9        7        9
# 7            Historically Black Prot      228       244      236      238
# 8                   Jehovahs Witness       20        27       24       24
# 9                             Jewish       19        19       25       25
#
#               $40-50k  $50-75k
# religion_id
# 0                  76      137
# 1                  35       70
# ...

# %%
pew.reset_index()
# Out:
#    religion_id                  religion   <$10k   $10-20k  $20-30k  $30-40k  \
# 0            0                  Agnostic      27        34       60       81
# 1            1                   Atheist      12        27       37       52
# 2            2                  Buddhist      27        21       30       34
# 3            3                  Catholic     418       617      732      670
# 4            4         Dont know/refused      15        14       15       11
# 5            5         Evangelical Prot      575       869     1064      982
# 6            6                    Hindu        1         9        7        9
# 7            7  Historically Black Prot      228       244      236      238
# 8            8         Jehovahs Witness       20        27       24       24
# 9            9                   Jewish       19        19       25       25
#
#     $40-50k  $50-75k
# 0        76      137
# 1        35       70
# 2        33       58
# 3       638     1116
# ...

# %%
pew
# Out:
#                              religion   <$10k   $10-20k  $20-30k  $30-40k  \
# religion_id
# 0                            Agnostic      27        34       60       81
# 1                             Atheist      12        27       37       52
# 2                            Buddhist      27        21       30       34
# 3                            Catholic     418       617      732      670
# 4                   Dont know/refused      15        14       15       11
# 5                   Evangelical Prot      575       869     1064      982
# 6                              Hindu        1         9        7        9
# 7            Historically Black Prot      228       244      236      238
# 8                   Jehovahs Witness       20        27       24       24
# 9                             Jewish       19        19       25       25
#
#               $40-50k  $50-75k
# religion_id
# 0                  76      137
# 1                  35       70
# ...

# %%
pew.dtypes
# Out:
# religion    object
#  <$10k       int64
#  $10-20k     int64
# $20-30k      int64
# $30-40k      int64
#  $40-50k     int64
# $50-75k      int64
# dtype: object

# %%
religion1=pd.melt(pew, id_vars=['religion'])

# %%
religion1
# Out:
#                     religion  variable  value
# 0                   Agnostic     <$10k     27
# 1                    Atheist     <$10k     12
# 2                   Buddhist     <$10k     27
# 3                   Catholic     <$10k    418
# 4          Dont know/refused     <$10k     15
# 5          Evangelical Prot      <$10k    575
# 6                     Hindu      <$10k      1
# 7   Historically Black Prot      <$10k    228
# 8          Jehovahs Witness      <$10k     20
# 9                    Jewish      <$10k     19
# 10                  Agnostic   $10-20k     34
# 11                   Atheist   $10-20k     27
# 12                  Buddhist   $10-20k     21
# 13                  Catholic   $10-20k    617
# 14         Dont know/refused   $10-20k     14
# 15         Evangelical Prot    $10-20k    869
# 16                    Hindu    $10-20k      9
# 17  Historically Black Prot    $10-20k    244
# 18         Jehovahs Witness    $10-20k     27
# ...

# %%
religion1= religion1.rename(columns={
    'variable':'income_range',
    'value':'frequency'
})

# %%
religion1
# Out:
#                     religion income_range  frequency
# 0                   Agnostic        <$10k         27
# 1                    Atheist        <$10k         12
# 2                   Buddhist        <$10k         27
# 3                   Catholic        <$10k        418
# 4          Dont know/refused        <$10k         15
# 5          Evangelical Prot         <$10k        575
# 6                     Hindu         <$10k          1
# 7   Historically Black Prot         <$10k        228
# 8          Jehovahs Witness         <$10k         20
# 9                    Jewish         <$10k         19
# 10                  Agnostic      $10-20k         34
# 11                   Atheist      $10-20k         27
# 12                  Buddhist      $10-20k         21
# 13                  Catholic      $10-20k        617
# 14         Dont know/refused      $10-20k         14
# 15         Evangelical Prot       $10-20k        869
# 16                    Hindu       $10-20k          9
# ...

# %%
religion1
# Out:
#                     religion income_range  frequency
# 0                   Agnostic        <$10k         27
# 1                    Atheist        <$10k         12
# 2                   Buddhist        <$10k         27
# 3                   Catholic        <$10k        418
# 4          Dont know/refused        <$10k         15
# 5          Evangelical Prot         <$10k        575
# 6                     Hindu         <$10k          1
# 7   Historically Black Prot         <$10k        228
# 8          Jehovahs Witness         <$10k         20
# 9                    Jewish         <$10k         19
# 10                  Agnostic      $10-20k         34
# 11                   Atheist      $10-20k         27
# 12                  Buddhist      $10-20k         21
# 13                  Catholic      $10-20k        617
# 14         Dont know/refused      $10-20k         14
# 15         Evangelical Prot       $10-20k        869
# 16                    Hindu       $10-20k          9
# ...

# %%
religion1.dtypes
# Out:
# religion        object
# income_range    object
# frequency        int64
# dtype: object

# %%
religion1['income_range'] = religion1['income_range'].astype(str)

# %%
religion1
# Out:
#                     religion income_range  frequency
# 0                   Agnostic        <$10k         27
# 1                    Atheist        <$10k         12
# 2                   Buddhist        <$10k         27
# 3                   Catholic        <$10k        418
# 4          Dont know/refused        <$10k         15
# 5          Evangelical Prot         <$10k        575
# 6                     Hindu         <$10k          1
# 7   Historically Black Prot         <$10k        228
# 8          Jehovahs Witness         <$10k         20
# 9                    Jewish         <$10k         19
# 10                  Agnostic      $10-20k         34
# 11                   Atheist      $10-20k         27
# 12                  Buddhist      $10-20k         21
# 13                  Catholic      $10-20k        617
# 14         Dont know/refused      $10-20k         14
# 15         Evangelical Prot       $10-20k        869
# 16                    Hindu       $10-20k          9
# ...

# %%
religion1.dtypes
# Out:
# religion        object
# income_range    object
# frequency        int64
# dtype: object

# %%
religion1.index.name = 'religion_id'

# %%
religion1
# Out:
#                              religion income_range  frequency
# religion_id
# 0                            Agnostic        <$10k         27
# 1                             Atheist        <$10k         12
# 2                            Buddhist        <$10k         27
# 3                            Catholic        <$10k        418
# 4                   Dont know/refused        <$10k         15
# 5                   Evangelical Prot         <$10k        575
# 6                              Hindu         <$10k          1
# 7            Historically Black Prot         <$10k        228
# 8                   Jehovahs Witness         <$10k         20
# 9                             Jewish         <$10k         19
# 10                           Agnostic      $10-20k         34
# 11                            Atheist      $10-20k         27
# 12                           Buddhist      $10-20k         21
# 13                           Catholic      $10-20k        617
# ...

# %%
religion1 = religion1.reset_index()

# %%
religion1
# Out:
#     religion_id                  religion income_range  frequency
# 0             0                  Agnostic        <$10k         27
# 1             1                   Atheist        <$10k         12
# 2             2                  Buddhist        <$10k         27
# 3             3                  Catholic        <$10k        418
# 4             4         Dont know/refused        <$10k         15
# 5             5         Evangelical Prot         <$10k        575
# 6             6                    Hindu         <$10k          1
# 7             7  Historically Black Prot         <$10k        228
# 8             8         Jehovahs Witness         <$10k         20
# 9             9                   Jewish         <$10k         19
# 10           10                  Agnostic      $10-20k         34
# 11           11                   Atheist      $10-20k         27
# 12           12                  Buddhist      $10-20k         21
# ...

# %%
religion1 = religion1.sort_values(['religion_id', 'religion'])

# %%
religion1
# Out:
#     religion_id                  religion income_range  frequency
# 0             0                  Agnostic        <$10k         27
# 1             1                   Atheist        <$10k         12
# 2             2                  Buddhist        <$10k         27
# 3             3                  Catholic        <$10k        418
# 4             4         Dont know/refused        <$10k         15
# 5             5         Evangelical Prot         <$10k        575
# 6             6                    Hindu         <$10k          1
# 7             7  Historically Black Prot         <$10k        228
# 8             8         Jehovahs Witness         <$10k         20
# 9             9                   Jewish         <$10k         19
# 10           10                  Agnostic      $10-20k         34
# 11           11                   Atheist      $10-20k         27
# 12           12                  Buddhist      $10-20k         21
# ...

# %%
del religion1['religion_id']

# %% [raw]
# religion1

# %%
religion1
# Out:
#                     religion income_range  frequency
# 0                   Agnostic        <$10k         27
# 1                    Atheist        <$10k         12
# 2                   Buddhist        <$10k         27
# 3                   Catholic        <$10k        418
# 4          Dont know/refused        <$10k         15
# 5          Evangelical Prot         <$10k        575
# 6                     Hindu         <$10k          1
# 7   Historically Black Prot         <$10k        228
# 8          Jehovahs Witness         <$10k         20
# 9                    Jewish         <$10k         19
# 10                  Agnostic      $10-20k         34
# 11                   Atheist      $10-20k         27
# 12                  Buddhist      $10-20k         21
# 13                  Catholic      $10-20k        617
# 14         Dont know/refused      $10-20k         14
# 15         Evangelical Prot       $10-20k        869
# 16                    Hindu       $10-20k          9
# ...
