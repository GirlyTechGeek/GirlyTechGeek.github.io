# %%
import boto3

# %%
! aws s3 ls
# Out:
# 2020-01-26 19:13:46 aponbucket
# 2020-02-22 13:21:07 blossom-data-eng-alexander
# 2020-02-21 11:42:43 blossom-data-eng-anna
# 2020-02-20 21:24:56 blossom-data-eng-dennis
# 2020-02-22 13:38:00 blossom-data-eng-ella
# 2020-02-21 20:04:46 blossom-data-eng-nana
# 2020-02-22 04:06:10 blossom-data-eng-sylvestre
# 2020-02-20 21:32:18 blossom-data-eng-test
# 2020-02-22 13:08:48 blossom-data-eng-timothy
# 2020-02-20 20:11:40 blossom-data-engs
# 2020-02-22 13:27:45 blossom-de-ayisha

# %%
s3 = boto3.client('s3')

# %%
s3.download_file('blossom-data-engs', 'free-7-million-company-dataset.zip', 'client_7million.zip')

# %%
import zipfile as ZipFile

# %%
with Zipfile.ZipFile('client_7million.zip', 'r') as client:
    client.extractall('my_env')

# %%
import pandas as pd
client = pd.read_csv('companies_sorted.csv')
client
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
client.dtypes
# Out:
# Unnamed: 0                     int64
# name                          object
# domain                        object
# year founded                  object
# industry                      object
# size range                    object
# locality                      object
# country                       object
# linkedin url                  object
# current employee estimate     object
# total employee estimate        int64
# Unnamed: 11                  float64
# dtype: object

# %%
client.shape
# Out:
# (204849, 12)

# %%
client.dropna(thresh = 4)
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
client.shape
# Out:
# (204849, 12)

# %%
client.sample(12)
# Out:
#         Unnamed: 0                                        name  \
# 39867      1912830                          al-quds university
# 76329      4156810            le royal monceau - raffles paris
# 136314     5969614                                        arte
# 107478      152021                          cms legal services
# 90038        20537         momentous insurance brokerage, inc.
# 116061      761226                                secret sales
# 171203     5457474            methaq takaful insurance company
# 13855      1759009  iran university of medical sciences (iums)
# 172077     5085329                               eikon digital
# 106944     2171352         fead centro de gestão empreendedora
# 111390     1976941                                     nextraq
# 198776     5546971                           lazzoni furniture
#
#                     domain year founded                   industry  \
# 39867           alquds.edu         1981           higher education
# ...

# %%
client[client.domain.notnull()]
# Out:
#         Unnamed: 0                          name             domain  \
# 0          5872184                           ibm            ibm.com
# 1          4425416     tata consultancy services            tcs.com
# 2            21074                     accenture      accenture.com
# 3          2309813                       us army         goarmy.com
# 4          1558607                            ey             ey.com
# ...            ...                           ...                ...
# 204844     4165370  caron transportation systems  carontransport.ca
# 204845     4859186                  ramada hotel  canaltahotels.com
# 204846     5831392       phelan construction ltd      phelans.co.uk
# 204847     4029001                        cebbco         cebbco.com
# 204848     4603252    laboratorio médico polanco      lmpolanco.com
#
#        year founded                             industry size range  \
# 0              1911  information technology and services     10001+
# ...

# %%
client.shape
# Out:
# (204849, 12)

# %%
client = client.dropna()
client
# Out:
#         Unnamed: 0                                          name  \
# 33937      1128772                                         sefcu
# 60470      2575117                                        icarda
# 67461      3951975              associated consulting engineers
# 158564      630876                          atlanta area council
# 160423     1232013                                           h3
# 172412     1973399  bayanat for mapping & surveying services llc
#
#                                                    domain    year founded  \
# 33937                                                 www       sefcu.com
# 60470    international center for agricultural researc...      icarda.org
# 67461                                                 ace    ace-intl.net
# 158564                              boy scouts of america  atlantabsa.org
# 160423                                               slow          h3.com
# ...

# %%
client.shape
# Out:
# (6, 12)

# %%
client.sample(4)
# Out:
#         Unnamed: 0                                          name  \
# 33937      1128772                                         sefcu
# 158564      630876                          atlanta area council
# 160423     1232013                                           h3
# 172412     1973399  bayanat for mapping & surveying services llc
#
#                         domain    year founded industry  \
# 33937                      www       sefcu.com     1934
# 158564   boy scouts of america  atlantabsa.org     1916
# 160423                    slow          h3.com     2007
# 172412      a mubadala company   bayanat.co.ae     2008
#
#                                 size range    locality  \
# 33937                              banking  501 - 1000
# 158564  non-profit organization management    51 - 200
# 160423                    food & beverages   201 - 500
# 172412                     defense & space    51 - 200
#
# ...

# %%
client
# Out:
#         Unnamed: 0                                          name  \
# 33937      1128772                                         sefcu
# 60470      2575117                                        icarda
# 67461      3951975              associated consulting engineers
# 158564      630876                          atlanta area council
# 160423     1232013                                           h3
# 172412     1973399  bayanat for mapping & surveying services llc
#
#                                                    domain    year founded  \
# 33937                                                 www       sefcu.com
# 60470    international center for agricultural researc...      icarda.org
# 67461                                                 ace    ace-intl.net
# 158564                              boy scouts of america  atlantabsa.org
# 160423                                               slow          h3.com
# ...

# %%
client.dtypes
# Out:
# Unnamed: 0                     int64
# name                          object
# domain                        object
# year founded                  object
# industry                      object
# size range                    object
# locality                      object
# country                       object
# linkedin url                  object
# current employee estimate     object
# total employee estimate        int64
# Unnamed: 11                  float64
# dtype: object

# %%
import pandas as pd
import pyarrow as pa
t = pa.Table.from_pandas(client)
client.to_parquet('free-data-7-million-dataset.parquet')

# %%
client.to_json('free-data-7-million-dataset.json.gzip', compression='gzip')

# %%
s3 = boto3.client('s3', region_name='eu-west-1')
bucket= 'blossom-data-eng-anna'
s3.upload_file('free-data-7-million-dataset.parquet', bucket, 'free-data-7-million-dataset.parquet')
s3.upload_file('free-data-7-million-dataset.json.gzip', bucket, 'free-data-7-million-dataset.json.gzip' )
